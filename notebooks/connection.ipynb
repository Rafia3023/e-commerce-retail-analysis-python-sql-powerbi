# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
import os 
import warnings

# %%
# Step 1: Connect to Postgreysql
username = "postgres"
password = "rafia123"
host = "localhost"
port = "5432"
database = "e_commerce"

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Step 2: Folder containing all CSV files
folder_path = r"R:\e-commerce-dataset\data"

# Step 3. Loop through each CSV file in that folder and import it
for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        file_path = os.path.join(folder_path,file)
        df = pd.read_csv(file_path)
        print(df.shape)
        
        # Step 4. Use file name (without .csv) as table name
        table_name = os.path.splitext(file)[0].lower()

        # Step 5. Load into PostgreSQL
        df.to_sql(table_name, engine,if_exists = "replace", index = False)
        print(f"import '{file}', as table'{table_name}'")

print("All CSV files loaded into PostgreSQL successfully!")
# Out:
# (99441, 5)
# import 'customers.csv', as table'customers'
# (1000163, 5)
# import 'geolocation.csv', as table'geolocation'
# (99441, 8)
# import 'orders.csv', as table'orders'
# (112650, 7)
# import 'order_item.csv', as table'order_item'
# (103886, 5)
# import 'order_payments.csv', as table'order_payments'
# (99224, 7)
# import 'order_reviews.csv', as table'order_reviews'
# (32951, 9)
# import 'products.csv', as table'products'
# (71, 2)
# import 'product_category_name_translation.csv', as table'product_category_name_translation'
# (3095, 4)
# import 'sellers.csv', as table'sellers'
# All CSV files loaded into PostgreSQL successfully!
